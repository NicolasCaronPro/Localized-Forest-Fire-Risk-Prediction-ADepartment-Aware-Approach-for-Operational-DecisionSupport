# %%
from tools_functions import *

path_to_target_datacube = Path('/media/caron/X9 Pro1/travaille/Thèse/Model/HexagonalScale/ST-GNN-for-wildifre-prediction/Prediction/Target/firepoint/bdiff/datacube/departement-13-bouches-du-rhone/2x2')

datacube = read_object('datacube.pkl', path_to_target_datacube)

# %%
datacube
# Out:
# <xarray.Dataset>
# Dimensions:      (latitude: 34, longitude: 52, date: 2574)
# Coordinates:
#   * latitude     (latitude) float64 43.9 43.88 43.86 43.84 ... 43.26 43.24 43.22
#   * longitude    (longitude) float64 4.276 4.305 4.334 ... 5.685 5.714 5.742
#   * date         (date) <U10 '2017-06-12' '2017-06-13' ... '2024-06-28'
# Data variables:
#     occurence    (latitude, longitude, date) float64 nan nan nan ... nan nan nan
#     burned_area  (latitude, longitude, date) float64 nan nan nan ... nan nan nan

# %%
import matplotlib.pyplot as plt

# On suppose que datacube est un xarray Dataset ou DataArray
# Et qu'on a une feature nommée 'temperature'

datacube['burned_area'].sum(dim=['date']).plot()
plt.title("Occurences")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
